# %% [markdown]
# # Replace with NaN

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('Energy Indicators.xls')

# %%
df = df.iloc[16:243]
df
# Out:
#      Unnamed: 0                                         Unnamed: 1  \
# 16          NaN                                        Afghanistan
# 17          NaN                                            Albania
# 18          NaN                                            Algeria
# 19          NaN                                     American Samoa
# 20          NaN                                            Andorra
# 21          NaN                                             Angola
# 22          NaN                                           Anguilla
# 23          NaN                                Antigua and Barbuda
# 24          NaN                                          Argentina
# 25          NaN                                            Armenia
# 26          NaN                                              Aruba
# 27          NaN                                          Australia
# 28          NaN                                            Austria
# ...

# %%
df.replace('...', np.nan, inplace = True)

# %%
df
# Out:
#      Unnamed: 0                                         Unnamed: 1  \
# 16          NaN                                        Afghanistan
# 17          NaN                                            Albania
# 18          NaN                                            Algeria
# 19          NaN                                     American Samoa
# 20          NaN                                            Andorra
# 21          NaN                                             Angola
# 22          NaN                                           Anguilla
# 23          NaN                                Antigua and Barbuda
# 24          NaN                                          Argentina
# 25          NaN                                            Armenia
# 26          NaN                                              Aruba
# 27          NaN                                          Australia
# 28          NaN                                            Austria
# ...
