# %% [markdown]
# # Drop Header and Footer

# %%
import pandas as pd

# %%
df = pd.read_excel('Energy Indicators.xls')

# %%
df
# Out:
#      Unnamed: 0                                         Unnamed: 1  \
# 0           NaN                                                NaN
# 1           NaN                                                NaN
# 2           NaN                                                NaN
# 3           NaN                                                NaN
# 4           NaN                                                NaN
# 5           NaN                                                NaN
# 6           NaN                                                NaN
# 7           NaN                                                NaN
# 8           NaN                                                NaN
# 9           NaN                                                NaN
# 10          NaN                                                NaN
# 11          NaN                                                NaN
# 12          NaN                                                NaN
# ...

# %% [markdown]
# ## Remove Header

# %%
df = df.iloc[16:]
df.head()
# Out:
#     Unnamed: 0      Unnamed: 1 Environmental Indicators: Energy Unnamed: 3  \
# 16         NaN     Afghanistan                      Afghanistan        321
# 17         NaN         Albania                          Albania        102
# 18         NaN         Algeria                          Algeria       1959
# 19         NaN  American Samoa                   American Samoa        ...
# 20         NaN         Andorra                          Andorra          9
#
#    Unnamed: 4 Unnamed: 5
# 16         10    78.6693
# 17         35        100
# 18         51    0.55101
# 19        ...   0.641026
# 20        121    88.6957

# %% [markdown]
# ## Remove Footer

# %%
df.tail(50)
# Out:
#      Unnamed: 0                                         Unnamed: 1  \
# 231         NaN                        United Republic of Tanzania
# 232         NaN                           United States of America
# 233         NaN                       United States Virgin Islands
# 234         NaN                                            Uruguay
# 235         NaN                                         Uzbekistan
# 236         NaN                                            Vanuatu
# 237         NaN                 Venezuela (Bolivarian Republic of)
# 238         NaN                                           Viet Nam
# 239         NaN                          Wallis and Futuna Islands
# 240         NaN                                              Yemen
# 241         NaN                                             Zambia
# 242         NaN                                           Zimbabwe
# 243         NaN                                                NaN
# ...

# %%
df = df.iloc[:227]
df.tail()
# Out:
#      Unnamed: 0                 Unnamed: 1 Environmental Indicators: Energy  \
# 238         NaN                   Viet Nam                         Viet Nam
# 239         NaN  Wallis and Futuna Islands        Wallis and Futuna Islands
# 240         NaN                      Yemen                            Yemen
# 241         NaN                     Zambia                           Zambia
# 242         NaN                   Zimbabwe                         Zimbabwe
#
#     Unnamed: 3 Unnamed: 4 Unnamed: 5
# 238       2554         28    45.3215
# 239          0         26          0
# 240        344         13          0
# 241        400         26    99.7147
# 242        480         32    52.5361
